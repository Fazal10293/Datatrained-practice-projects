# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
avc=pd.read_csv('avocados.csv')

# %%
avc
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0             0.0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1             1.0  20-12-2015          1.35      54876.98   674.28   44638.81
# 2             2.0  13-12-2015          0.93     118220.22   794.70  109149.67
# 3             3.0  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4             4.0  29-11-2015          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 16463         NaN         NaN           NaN           NaN      NaN        NaN
# 16464         NaN         NaN           NaN           NaN      NaN        NaN
# 16465         NaN         NaN           NaN           NaN      NaN        NaN
# 16466         NaN         NaN           NaN           NaN      NaN        NaN
# 16467         NaN         NaN           NaN           NaN      NaN        NaN
#
# ...

# %%
avc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16468 entries, 0 to 16467
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1517 non-null   float64
#  1   Date          1517 non-null   object
#  2   AveragePrice  1517 non-null   float64
#  3   Total Volume  1517 non-null   float64
#  4   4046          1517 non-null   float64
#  5   4225          1517 non-null   float64
#  6   4770          1517 non-null   float64
#  7   Total Bags    1517 non-null   float64
#  8   Small Bags    1517 non-null   float64
#  9   Large Bags    1517 non-null   float64
#  10  XLarge Bags   1517 non-null   float64
#  11  type          1517 non-null   object
#  12  year          1517 non-null   float64
#  13  region        1517 non-null   object
# dtypes: float64(11), object(3)
# memory usage: 1.8+ MB

# %%
avc.describe()
# Out:
#         Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  1517.000000   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03
# mean     26.995386      1.074990  1.601879e+06  6.464387e+05  6.114375e+05
# std      14.848287      0.188891  4.433143e+06  1.947614e+06  1.672906e+06
# min       0.000000      0.490000  3.875074e+04  4.677200e+02  1.783770e+03
# 25%      14.000000      0.980000  1.474700e+05  2.040034e+04  4.147606e+04
# 50%      29.000000      1.080000  4.027919e+05  8.175117e+04  1.186649e+05
# 75%      39.000000      1.190000  9.819751e+05  3.775785e+05  4.851503e+05
# max      51.000000      1.680000  4.465546e+07  1.893304e+07  1.895648e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000
# mean   5.040550e+04  2.935974e+05  2.487736e+05  4.264205e+04    2181.771074
# ...

# %%
avc=avc.head(1517)

# %%
avc
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume      4046       4225  \
# 0            0.0  27-12-2015          1.33      64236.62   1036.74   54454.85
# 1            1.0  20-12-2015          1.35      54876.98    674.28   44638.81
# 2            2.0  13-12-2015          0.93     118220.22    794.70  109149.67
# 3            3.0  06-12-2015          1.08      78992.15   1132.00   71976.41
# 4            4.0  29-11-2015          1.28      51039.60    941.48   43838.39
# ...          ...         ...           ...           ...       ...        ...
# 1512        10.0  16-10-2016          1.39     190846.01  57529.11   56366.66
# 1513        11.0  09-10-2016          1.51     178235.75  43325.87   52189.61
# 1514        12.0  02-10-2016          1.48     178410.82  46364.75   52893.38
# 1515        13.0  25-09-2016          1.47     189131.52  54110.79   53593.58
# 1516        14.0  18-09-2016          1.43     182978.30  43116.41   54193.42
#
# ...

# %%
avc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1517 entries, 0 to 1516
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1517 non-null   float64
#  1   Date          1517 non-null   object
#  2   AveragePrice  1517 non-null   float64
#  3   Total Volume  1517 non-null   float64
#  4   4046          1517 non-null   float64
#  5   4225          1517 non-null   float64
#  6   4770          1517 non-null   float64
#  7   Total Bags    1517 non-null   float64
#  8   Small Bags    1517 non-null   float64
#  9   Large Bags    1517 non-null   float64
#  10  XLarge Bags   1517 non-null   float64
#  11  type          1517 non-null   object
#  12  year          1517 non-null   float64
#  13  region        1517 non-null   object
# dtypes: float64(11), object(3)
# memory usage: 166.0+ KB

# %%
avc.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
avc['region'].value_counts()
# Out:
# California             76
# Albany                 67
# Boise                  65
# BaltimoreWashington    65
# Boston                 62
# Atlanta                54
# PhoenixTucson          52
# BuffaloRochester       51
# Spokane                49
# Columbus               47
# NewYork                44
# Jacksonville           41
# Detroit                40
# SouthCentral           39
# SanDiego               38
# West                   36
# Tampa                  34
# Louisville             34
# Charlotte              31
# Portland               30
# Houston                29
# NorthernNewEngland     29
# WestTexNewMexico       27
# Nashville              25
# TotalUS                25
# Denver                 24
# SouthCarolina          24
# GrandRapids            23
# Chicago                23
# Pittsburgh             22
# Orlando                21
# RichmondNorfolk        21
# HarrisburgScranton     19
# Syracuse               19
# Midsouth               18
# ...

# %%
avc['Small Bags'].value_counts()
# Out:
# 15997.43     1
# 48304.30     1
# 8876.65      1
# 9586.80      1
# 27736.40     1
#             ..
# 7946.78      1
# 9533.88      1
# 181854.71    1
# 34448.65     1
# 235274.47    1
# Name: Small Bags, Length: 1517, dtype: int64

# %%
avc.dtypes
# Out:
# Unnamed: 0      float64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year            float64
# region           object
# dtype: object

# %%
#univariate analysis

# %%
avc.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
avc['AveragePrice'].plot.hist()

# %% [markdown]
# the average price lies between 1 to 1.2

# %%
avc['Small Bags'].plot.hist()

# %%
plt.figure(figsize=(16,6))
plt.xticks(rotation=90)
plt.title( 'Region wise Avocado count')
sns.countplot(x='region',data=avc)

# %% [markdown]
# this graph shows Region wise avocado counts

# %%
sns.countplot(x='type',data=avc)

# %% [markdown]
# In this dataset we have only conventional type of Avocado.

# %%
#Bivariate analysis

# %%
avc.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
plt.figure(figsize=(16,6))
plt.xticks(rotation=90)
plt.yticks(rotation=45)
plt.scatter(x='region',y='Date',data=avc)

# %%
plt.figure(figsize=(16,6))
plt.xticks(rotation=90)
plt.yticks(rotation=45)
sns.barplot(x='region',y='AveragePrice',data=avc)

# %%
corr=avc.corr()

# %%
corr
# Out:
#               Unnamed: 0  AveragePrice  Total Volume      4046      4225  \
# Unnamed: 0      1.000000     -0.075531      0.091934  0.092013  0.093566
# AveragePrice   -0.075531      1.000000     -0.140470 -0.190096 -0.092084
# Total Volume    0.091934     -0.140470      1.000000  0.985568  0.987154
# 4046            0.092013     -0.190096      0.985568  1.000000  0.951952
# 4225            0.093566     -0.092084      0.987154  0.951952  1.000000
# 4770            0.075647     -0.100567      0.934347  0.898570  0.927757
# Total Bags      0.081007     -0.111597      0.967689  0.930395  0.951779
# Small Bags      0.083485     -0.097682      0.960642  0.922278  0.943988
# Large Bags      0.065364     -0.177480      0.910226  0.884229  0.900496
# XLarge Bags    -0.050993     -0.048284      0.521717  0.474063  0.504718
# year           -0.012854      0.178683     -0.004189 -0.040439 -0.007254
#
#                   4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(corr,annot=True)

# %% [markdown]
# for Average price,, year is little bit positively correlated, rest all negatively correlated with the data.
# we can drop Xlarge bags and 4225, as they are weakly negative correlated

# %%
sns.distplot(avc['AveragePrice'])

# %% [markdown]
# here the data is normally distributed

# %%
#Checking for outliers

# %%
avc['AveragePrice'].plot.box()

# %%
avc['XLarge Bags'].plot.box()

# %% [markdown]
# as we have seen in heatmap, XLarge Bags and Small are weakly negative correlated we can drop this column and need to remove ouliers for target variables

# %%
avc
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume      4046       4225  \
# 0            0.0  27-12-2015          1.33      64236.62   1036.74   54454.85
# 1            1.0  20-12-2015          1.35      54876.98    674.28   44638.81
# 2            2.0  13-12-2015          0.93     118220.22    794.70  109149.67
# 3            3.0  06-12-2015          1.08      78992.15   1132.00   71976.41
# 4            4.0  29-11-2015          1.28      51039.60    941.48   43838.39
# ...          ...         ...           ...           ...       ...        ...
# 1512        10.0  16-10-2016          1.39     190846.01  57529.11   56366.66
# 1513        11.0  09-10-2016          1.51     178235.75  43325.87   52189.61
# 1514        12.0  02-10-2016          1.48     178410.82  46364.75   52893.38
# 1515        13.0  25-09-2016          1.47     189131.52  54110.79   53593.58
# 1516        14.0  18-09-2016          1.43     182978.30  43116.41   54193.42
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
avc['region']=le.fit_transform(avc['region'])
avc['region']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1512    7
# 1513    7
# 1514    7
# 1515    7
# 1516    7
# Name: region, Length: 1517, dtype: int32

# %%
#As all the items is conventional hence dropping type

# %%
avc.drop(['type'],axis=1,inplace=True)

# %%
avc
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume      4046       4225  \
# 0            0.0  27-12-2015          1.33      64236.62   1036.74   54454.85
# 1            1.0  20-12-2015          1.35      54876.98    674.28   44638.81
# 2            2.0  13-12-2015          0.93     118220.22    794.70  109149.67
# 3            3.0  06-12-2015          1.08      78992.15   1132.00   71976.41
# 4            4.0  29-11-2015          1.28      51039.60    941.48   43838.39
# ...          ...         ...           ...           ...       ...        ...
# 1512        10.0  16-10-2016          1.39     190846.01  57529.11   56366.66
# 1513        11.0  09-10-2016          1.51     178235.75  43325.87   52189.61
# 1514        12.0  02-10-2016          1.48     178410.82  46364.75   52893.38
# 1515        13.0  25-09-2016          1.47     189131.52  54110.79   53593.58
# 1516        14.0  18-09-2016          1.43     182978.30  43116.41   54193.42
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
avc['Date']=le.fit_transform(avc['Date'])
avc['Date']
# Out:
# 0       92
# 1       68
# 2       44
# 3       20
# 4       98
#         ..
# 1512    53
# 1513    29
# 1514     5
# 1515    83
# 1516    59
# Name: Date, Length: 1517, dtype: int32

# %%
avc
# Out:
#       Unnamed: 0  Date  AveragePrice  Total Volume      4046       4225  \
# 0            0.0    92          1.33      64236.62   1036.74   54454.85
# 1            1.0    68          1.35      54876.98    674.28   44638.81
# 2            2.0    44          0.93     118220.22    794.70  109149.67
# 3            3.0    20          1.08      78992.15   1132.00   71976.41
# 4            4.0    98          1.28      51039.60    941.48   43838.39
# ...          ...   ...           ...           ...       ...        ...
# 1512        10.0    53          1.39     190846.01  57529.11   56366.66
# 1513        11.0    29          1.51     178235.75  43325.87   52189.61
# 1514        12.0     5          1.48     178410.82  46364.75   52893.38
# 1515        13.0    83          1.47     189131.52  54110.79   53593.58
# 1516        14.0    59          1.43     182978.30  43116.41   54193.42
#
#           4770  Total Bags  Small Bags  Large Bags  XLarge Bags    year  \
# ...

# %%
avc.skew()
# Out:
# Unnamed: 0     -0.234824
# Date            0.012623
# AveragePrice   -0.109444
# Total Volume    6.200138
# 4046            6.051830
# 4225            6.394926
# 4770            5.405164
# Total Bags      5.366378
# Small Bags      5.355185
# Large Bags      5.144495
# XLarge Bags     5.775077
# year            1.828332
# region          0.288146
# dtype: float64

# %%
for col in avc.columns:
    if avc[col].skew()>0.55:
        avc[col]=np.log1p(avc[col])

# %%
avc.skew()
# Out:
# Unnamed: 0     -0.234824
# Date            0.012623
# AveragePrice   -0.109444
# Total Volume    0.667468
# 4046           -0.160268
# 4225            0.184436
# 4770           -0.355508
# Total Bags      0.695502
# Small Bags      0.713843
# Large Bags     -0.912766
# XLarge Bags     0.783913
# year            1.828332
# region          0.288146
# dtype: float64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import warnings
warnings.filterwarnings('ignore')

# %%
x=avc.iloc[:,0:-1]
x
# Out:
#       Unnamed: 0  Date  AveragePrice  Total Volume       4046       4225  \
# 0            0.0    92          1.33     11.070344   6.944801  10.905146
# 1            1.0    68          1.35     10.912867   6.515127  10.706381
# 2            2.0    44          0.93     11.680313   6.679222  11.600485
# 3            3.0    20          1.08     11.277116   7.032624  11.184108
# 4            4.0    98          1.28     10.840377   6.848515  10.688288
# ...          ...   ...           ...           ...        ...        ...
# 1512        10.0    53          1.39     12.159227  10.960064  10.939651
# 1513        11.0    29          1.51     12.090868  10.676528  10.862658
# 1514        12.0     5          1.48     12.091850  10.744316  10.876052
# 1515        13.0    83          1.47     12.150203  10.898807  10.889203
# 1516        14.0    59          1.43     12.117128  10.671682  10.900333
#
#           4770  Total Bags  Small Bags  Large Bags  XLarge Bags      year
# ...

# %%
# Standard scaler for input variables
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
z=sc.fit_transform(x)
z=pd.DataFrame(z,columns=x.columns)

# %%
z
# Out:
#       Unnamed: 0      Date  AveragePrice  Total Volume      4046      4225  \
# 0       -1.81868  1.377766      1.350481     -1.356762 -1.828162 -0.567524
# 1       -1.75131  0.578580      1.456397     -1.466387 -2.012069 -0.684233
# 2       -1.68394 -0.220606     -0.767838     -0.932139 -1.941834 -0.159241
# 3       -1.61657 -1.019792      0.026531     -1.212820 -1.790572 -0.403726
# 4       -1.54920  1.577562      1.085691     -1.516851 -1.869374 -0.694856
# ...          ...       ...           ...           ...       ...       ...
# 1512    -1.14498  0.079089      1.668229     -0.598749 -0.109561 -0.547264
# 1513    -1.07761 -0.720097      2.303724     -0.646336 -0.230919 -0.592472
# 1514    -1.01024 -1.519283      2.144850     -0.645653 -0.201904 -0.584607
# 1515    -0.94287  1.078071      2.091892     -0.605031 -0.135779 -0.576885
# 1516    -0.87550  0.278885      1.880061     -0.628056 -0.232993 -0.570350
#
# ...

# %%
x=z

# %%
y=avc.iloc[:,-1]

# %%
y=pd.DataFrame(y)
y
# Out:
#       region
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 1512       7
# 1513       7
# 1514       7
# 1515       7
# 1516       7
#
# [1517 rows x 1 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=45,test_size=.25)

# %%
x_train.shape
# Out:
# (1137, 12)

# %%
y_train.shape
# Out:
# (1137, 1)

# %%
x_test.shape
# Out:
# (380, 12)

# %%
y_test.shape
# Out:
# (380, 1)

# %%
svc=SVC(kernel='poly')
svc.fit(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.6842105263157895
# [[21  0  0 ...  0  0  0]
#  [ 0  8  0 ...  0  0  0]
#  [ 0  0 18 ...  0  0  0]
#  ...
#  [ 0  0  0 ...  2  0  0]
#  [ 0  0  0 ...  0  7  0]
#  [ 0  1  0 ...  0  0  4]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.98        22
#            1       0.11      1.00      0.20         8
#            2       0.40      1.00      0.57        18
#            3       1.00      1.00      1.00        16
#            4       1.00      1.00      1.00        12
#            5       1.00      1.00      1.00        12
#            6       1.00      1.00      1.00        17
#            7       1.00      0.70      0.82        10
#            8       0.00      0.00      0.00         6
#            9       0.85      1.00      0.92        11
#           10       0.00      0.00      0.00         3
#           11       1.00      0.25      0.40         4
#           12       1.00      0.93      0.96        14
# ...

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
preddtc=dtc.predict(x_test)
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 0.8763157894736842
# [[20  0  0 ...  0  0  0]
#  [ 0  7  0 ...  0  0  0]
#  [ 0  0 15 ...  0  0  0]
#  ...
#  [ 0  0  0 ...  2  0  0]
#  [ 0  0  0 ...  0  6  0]
#  [ 0  0  0 ...  0  0  3]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95        22
#            1       0.54      0.88      0.67         8
#            2       0.94      0.83      0.88        18
#            3       0.89      1.00      0.94        16
#            4       0.91      0.83      0.87        12
#            5       0.92      0.92      0.92        12
#            6       1.00      0.94      0.97        17
#            7       1.00      0.80      0.89        10
#            8       1.00      1.00      1.00         6
#            9       0.91      0.91      0.91        11
#           10       0.40      0.67      0.50         3
#           11       0.60      0.75      0.67         4
#           12       0.87      0.93      0.90        14
# ...

# %%
#hyper parameter tuning, DTC is best so using for GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV
dtc1=DecisionTreeClassifier()
parameters={'alpha':[0.001,0.01,0.1,1],'random_state':range(42,100)}
            clf=GridSearchCV(dtc1,parameters)
            clf.fit(x,y)
            clf.best_params_
# Out:
#   File "<ipython-input-56-862ef27b2ec3>", line 4
#     clf=GridSearchCV(dtc1,parameters)
#     ^
# IndentationError: unexpected indent

# %%
import pickle
filename='Avocado.pkl'
pickle.dump(dtc,open(filename, 'wb'))
