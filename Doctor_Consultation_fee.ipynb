# %%
import pandas as pd

# %%
dr=pd.read_csv('Doctortrain')

# %%
dr
# Out:
#                        Qualification           Experience Rating  \
# 0              BHMS, MD - Homeopathy  24 years experience   100%
# 1       BAMS, MD - Ayurveda Medicine  12 years experience    98%
# 2     MBBS, MS - Otorhinolaryngology   9 years experience    NaN
# 3                BSc - Zoology, BAMS  12 years experience    NaN
# 4                               BAMS  20 years experience   100%
# ...                              ...                  ...    ...
# 5956                  MBBS, MS - ENT  19 years experience    98%
# 5957                            MBBS  33 years experience    NaN
# 5958                            MBBS  41 years experience    97%
# 5959     MBBS, MD - General Medicine  15 years experience    90%
# 5960         BDS, MDS - Orthodontics  17 years experience   100%
#
#                               Place           Profile  \
# 0               Kakkanad, Ernakulam         Homeopath
# 1             Whitefield, Bangalore          Ayurveda
# ...

# %%
dr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5961 entries, 0 to 5960
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Qualification       5961 non-null   object
#  1   Experience          5961 non-null   object
#  2   Rating              2659 non-null   object
#  3   Place               5936 non-null   object
#  4   Profile             5961 non-null   object
#  5   Miscellaneous_Info  3341 non-null   object
#  6   Fees                5961 non-null   int64
# dtypes: int64(1), object(6)
# memory usage: 326.1+ KB

# %%
# Rating, Miscellenous info,Place has null values

# %%
dr.columns
# Out:
# Index(['Qualification', 'Experience', 'Rating', 'Place', 'Profile',
#        'Miscellaneous_Info', 'Fees'],
#       dtype='object')

# %%
dr.shape
# Out:
# (5961, 7)

# %%
dr.describe()
# Out:
#               Fees
# count  5961.000000
# mean    307.944640
# std     190.920373
# min       5.000000
# 25%     150.000000
# 50%     300.000000
# 75%     500.000000
# max     950.000000

# %%
# Max fee was Rs 950 and min fee was Rs 5

# %%
dr.dtypes
# Out:
# Qualification         object
# Experience            object
# Rating                object
# Place                 object
# Profile               object
# Miscellaneous_Info    object
# Fees                   int64
# dtype: object

# %%
dr.isnull().sum()
# Out:
# Qualification            0
# Experience               0
# Rating                3302
# Place                   25
# Profile                  0
# Miscellaneous_Info    2620
# Fees                     0
# dtype: int64

# %%
dr.describe()
# Out:
#               Fees
# count  5961.000000
# mean    307.944640
# std     190.920373
# min       5.000000
# 25%     150.000000
# 50%     300.000000
# 75%     500.000000
# max     950.000000

# %%
dr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5961 entries, 0 to 5960
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Qualification       5961 non-null   object
#  1   Experience          5961 non-null   object
#  2   Rating              2659 non-null   object
#  3   Place               5936 non-null   object
#  4   Profile             5961 non-null   object
#  5   Miscellaneous_Info  3341 non-null   object
#  6   Fees                5961 non-null   int64
# dtypes: int64(1), object(6)
# memory usage: 326.1+ KB

# %%
for i in dr['Experience'].value_counts().index:
    rd=i.split()
    dr['Experience'].replace(i,int(rd[0]),inplace=True)

# %%
dr
# Out:
#                        Qualification  Experience Rating  \
# 0              BHMS, MD - Homeopathy          24   100%
# 1       BAMS, MD - Ayurveda Medicine          12    98%
# 2     MBBS, MS - Otorhinolaryngology           9    NaN
# 3                BSc - Zoology, BAMS          12    NaN
# 4                               BAMS          20   100%
# ...                              ...         ...    ...
# 5956                  MBBS, MS - ENT          19    98%
# 5957                            MBBS          33    NaN
# 5958                            MBBS          41    97%
# 5959     MBBS, MD - General Medicine          15    90%
# 5960         BDS, MDS - Orthodontics          17   100%
#
#                               Place           Profile  \
# 0               Kakkanad, Ernakulam         Homeopath
# 1             Whitefield, Bangalore          Ayurveda
# 2        Mathikere - BEL, Bangalore    ENT Specialist
# 3      Bannerghatta Road, Bangalore          Ayurveda
# ...

# %% [markdown]
# from the above step we have changed Experience column into numbers

# %%
dr['Area']=dr['Place'].str.rsplit(',',1).str.get(0)
dr['City']=dr['Place'].str.rsplit(',',1).str.get(1)

# %%
dr
# Out:
#                        Qualification  Experience Rating  \
# 0              BHMS, MD - Homeopathy          24   100%
# 1       BAMS, MD - Ayurveda Medicine          12    98%
# 2     MBBS, MS - Otorhinolaryngology           9    NaN
# 3                BSc - Zoology, BAMS          12    NaN
# 4                               BAMS          20   100%
# ...                              ...         ...    ...
# 5956                  MBBS, MS - ENT          19    98%
# 5957                            MBBS          33    NaN
# 5958                            MBBS          41    97%
# 5959     MBBS, MD - General Medicine          15    90%
# 5960         BDS, MDS - Orthodontics          17   100%
#
#                               Place           Profile  \
# 0               Kakkanad, Ernakulam         Homeopath
# 1             Whitefield, Bangalore          Ayurveda
# 2        Mathikere - BEL, Bangalore    ENT Specialist
# 3      Bannerghatta Road, Bangalore          Ayurveda
# ...

# %%
# from this we are breaking place into Area and City

# %%
dr['Rating'].fillna('-99999%',inplace=True)
for i in dr['Rating'].value_counts().index:
    dr['Rating'].replace(i,int(i[:-1]),inplace=True)

# %%
dr
# Out:
#                        Qualification  Experience  Rating  \
# 0              BHMS, MD - Homeopathy          24     100
# 1       BAMS, MD - Ayurveda Medicine          12      98
# 2     MBBS, MS - Otorhinolaryngology           9  -99999
# 3                BSc - Zoology, BAMS          12  -99999
# 4                               BAMS          20     100
# ...                              ...         ...     ...
# 5956                  MBBS, MS - ENT          19      98
# 5957                            MBBS          33  -99999
# 5958                            MBBS          41      97
# 5959     MBBS, MD - General Medicine          15      90
# 5960         BDS, MDS - Orthodontics          17     100
#
#                               Place           Profile  \
# 0               Kakkanad, Ernakulam         Homeopath
# 1             Whitefield, Bangalore          Ayurveda
# 2        Mathikere - BEL, Bangalore    ENT Specialist
# 3      Bannerghatta Road, Bangalore          Ayurveda
# ...

# %%
import seaborn as sns
sns.distplot(dr['Rating'],bins=10)

# %%
import matplotlib.pyplot as plt
sns.distplot(dr['Fees'],bins=10)
plt.title('Distribution of Dr Fees')
plt.xlabel('Amount')
# Out:
# Text(0.5, 0, 'Amount')

# %%
plt.figure(figsize=(20,14))
sns.countplot(x='Rating',data=dr)
plt.ylabel('Counts')
plt.xlabel('Rating')
plt.title('Ratings given by patient')
plt.show()
print(dr['Rating'].value_counts())
# Out:
# -99999    3302
#  100       684
#  98        290
#  99        259
#  97        241
#  96        220
#  95        178
#  94        115
#  93        109
#  92         66
#  90         66
#  91         60
#  89         42
#  88         41
#  85         27
#  82         23
#  83         21
#  86         21
#  80         19
#  77         16
#  87         14
#  84         13
#  79         13
#  67         12
#  81         12
#  71          9
#  76          9
#  75          8
#  73          8
#  74          7
#  60          7
#  78          6
#  56          5
#  68          5
#  69          4
#  70          4
#  57          3
#  72          3
#  33          2
#  64          2
#  63          2
#  62          2
#  55          2
#  48          1
#  40          1
#  7           1
#  65          1
#  45          1
#  53          1
#  47          1
#  58          1
#  36          1
# Name: Rating, dtype: int64

# %%
plt.figure(figsize=(5,4))
sns.countplot(x='Profile',data=dr)
plt.xticks(rotation=20)
plt.ylabel('Counts')
plt.xlabel('Profile')
plt.title('category')
plt.show()
print(dr['Profile'].value_counts())
# Out:
# Dentist             1397
# General Medicine    1173
# Dermatologists      1034
# Homeopath            843
# Ayurveda             786
# ENT Specialist       728
# Name: Profile, dtype: int64

# %% [markdown]
# This shows that many people visted frequently for Dentsist and general medicines

# %%
#Bi variate analysis

# %%
plt.figure(figsize=(5,4))
sns.countplot(x='City',data=dr)
plt.xticks(rotation=20)
plt.ylabel('Counts')
plt.xlabel('City')
plt.title('category')
plt.show()
print(dr['City'].value_counts())
# Out:
#  Bangalore             1258
#  Mumbai                1219
#  Delhi                 1185
#  Hyderabad              951
#  Chennai                855
#  Coimbatore             228
#  Ernakulam              153
#  Thiruvananthapuram      86
# Name: City, dtype: int64

# %% [markdown]
# This above graph shows people who visited hospital city wise

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation=90)
plt.title( 'Region')
sns.barplot(x='City',y='Fees', data=dr)
print(dr.groupby('City')['Fees'].value_counts())
# Out:
# City                 Fees
#  Bangalore           300     229
#                      500     204
#                      200     185
#                      100     147
#                      400     147
#                             ...
#  Thiruvananthapuram  350       2
#                      500       2
#                      5         1
#                      80        1
#                      250       1
# Name: Fees, Length: 147, dtype: int64

# %% [markdown]
# here we can see delhi and banglore has very high doctor consultation fees

# %%
plt.figure(figsize=(6,5))
plt.xticks(rotation=90)
plt.title( 'Region')
ljj

# %% [markdown]
# ENT and Dermatologists earn more when it comes to the fees.

# %%
plt.figure(figsize=(16,6))
plt.xticks(rotation=90)
plt.title( 'Region')
sns.barplot(x='Experience',y='Fees', data=dr)

# %% [markdown]
# This graph shows that if u have experience that doesnt matter you should have the skills .

# %%
#we have separated area and city column hence dropping Place
dr.drop(['Place'],axis=1,inplace=True)

# %%
dr
# Out:
#                        Qualification  Experience  Rating           Profile  \
# 0              BHMS, MD - Homeopathy          24     100         Homeopath
# 1       BAMS, MD - Ayurveda Medicine          12      98          Ayurveda
# 2     MBBS, MS - Otorhinolaryngology           9  -99999    ENT Specialist
# 3                BSc - Zoology, BAMS          12  -99999          Ayurveda
# 4                               BAMS          20     100          Ayurveda
# ...                              ...         ...     ...               ...
# 5956                  MBBS, MS - ENT          19      98    ENT Specialist
# 5957                            MBBS          33  -99999  General Medicine
# 5958                            MBBS          41      97  General Medicine
# 5959     MBBS, MD - General Medicine          15      90  General Medicine
# 5960         BDS, MDS - Orthodontics          17     100           Dentist
#
#                                      Miscellaneous_Info  Fees  \
# ...

# %%
#MultiVariate Analysis

# %%
df_cor=dr.corr()

# %%
df_cor
# Out:
#             Experience    Rating      Fees
# Experience    1.000000 -0.019049  0.002117
# Rating       -0.019049  1.000000  0.164256
# Fees          0.002117  0.164256  1.000000

# %%
sns.heatmap(df_cor,annot=True)

# %%
dr['Fees'].plot.box()

# %%
dr['Experience'].plot.box()

# %% [markdown]
# There is some outliers present in data

# %%
dr.columns
# Out:
# Index(['Qualification', 'Experience', 'Rating', 'Profile',
#        'Miscellaneous_Info', 'Fees', 'Area', 'City'],
#       dtype='object')

# %%
dr.skew()
# Out:
# Experience    0.991089
# Rating        0.217056
# Fees          0.751870
# dtype: float64

# %% [markdown]
# Seems the data looks fine with Skewness

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
dr['Qualification']=le.fit_transform(dr['Qualification'])
dr['Qualification']
# Out:
# 0        401
# 1         73
# 2       1135
# 3        464
# 4         10
#         ...
# 5956    1075
# 5957     596
# 5958     596
# 5959     943
# 5960     243
# Name: Qualification, Length: 5961, dtype: int64

# %%
dr['City'].unique
# Out:
# <bound method Series.unique of 0        Ernakulam
# 1        Bangalore
# 2        Bangalore
# 3        Bangalore
# 4          Chennai
#            ...
# 5956     Bangalore
# 5957       Chennai
# 5958         Delhi
# 5959        Mumbai
# 5960         Delhi
# Name: City, Length: 5961, dtype: object>

# %%
import re
dr['City']=dr['City'].apply(lambda x: re.sub(' +','',str(x)))

# %%
import re
dr['Area']=dr['Area'].apply(lambda x: re.sub(' +','',str(x)))

# %%
import re
dr['Qualification']=dr['Qualification'].apply(lambda x: re.sub(' +','',str(x)))

# %%
import re
dr['Experience']=dr['Experience'].apply(lambda x: re.sub(' +','',str(x)))

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
columns=['Qualification','Experience']
for col in columns:
    dr[col]=le.fit_transform(dr[col])

# %%
dr
# Out:
#       Qualification  Experience  Rating  Profile  \
# 0               757          16      51        5
# 1              1121           3      49        0
# 2               153          62       0        3
# 3               826           3       0        0
# 4                 2          11      51        0
# ...             ...         ...     ...      ...
# 5956             86          10      49        3
# 5957            972          26       0        4
# 5958            972          35      48        4
# 5959           1358           6      41        4
# 5960            581           8      51        1
#
#                                      Miscellaneous_Info  Fees  \
# 0                  100% 16 Feedback Kakkanad, Ernakulam   100
# 1                 98% 76 Feedback Whitefield, Bangalore   350
# 2                                                   NaN   300
# 3     Bannerghatta Road, Bangalore ₹250 Available on...   250
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
columns=['Area','City']
for col in columns:
    dr[col]=le.fit_transform(dr[col])

# %%
dr
# Out:
#       Qualification  Experience  Rating  Profile  \
# 0               757          16      51        5
# 1              1121           3      49        0
# 2               153          62       0        3
# 3               826           3       0        0
# 4                 2          11      51        0
# ...             ...         ...     ...      ...
# 5956             86          10      49        3
# 5957            972          26       0        4
# 5958            972          35      48        4
# 5959           1358           6      41        4
# 5960            581           8      51        1
#
#                                      Miscellaneous_Info  Fees  Area  City
# 0                  100% 16 Feedback Kakkanad, Ernakulam   100   297     4
# 1                 98% 76 Feedback Whitefield, Bangalore   350   856     0
# 2                                                   NaN   300   453     0
# 3     Bannerghatta Road, Bangalore ₹250 Available on...   250    68     0
# ...

# %% [markdown]
# hence we have used label encoder to convert the data and will be giving it to models

# %%
dr.drop(['Miscellaneous_Info'],axis=1,inplace=True)

# %%
dr
# Out:
#       Qualification  Experience  Rating  Profile  Fees  Area  City
# 0               757          16      51        5   100   297     4
# 1              1121           3      49        0   350   856     0
# 2               153          62       0        3   300   453     0
# 3               826           3       0        0   250    68     0
# 4                 2          11      51        0   250   336     1
# ...             ...         ...     ...      ...   ...   ...   ...
# 5956             86          10      49        3   300    70     0
# 5957            972          26       0        4   100   536     1
# 5958            972          35      48        4   600   216     3
# 5959           1358           6      41        4   100   841     6
# 5960            581           8      51        1   200   598     3
#
# [5961 rows x 7 columns]

# %%
x=dr.drop(['Fees'],axis=1)
x
# Out:
#       Qualification  Experience  Rating  Profile  Area  City
# 0               757          16      51        5   297     4
# 1              1121           3      49        0   856     0
# 2               153          62       0        3   453     0
# 3               826           3       0        0    68     0
# 4                 2          11      51        0   336     1
# ...             ...         ...     ...      ...   ...   ...
# 5956             86          10      49        3    70     0
# 5957            972          26       0        4   536     1
# 5958            972          35      48        4   216     3
# 5959           1358           6      41        4   841     6
# 5960            581           8      51        1   598     3
#
# [5961 rows x 6 columns]

# %%
y=dr['Fees']
y
# Out:
# 0       100
# 1       350
# 2       300
# 3       250
# 4       250
#        ...
# 5956    300
# 5957    100
# 5958    600
# 5959    100
# 5960    200
# Name: Fees, Length: 5961, dtype: int64

# %%
#scaling the input variable

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
z=sc.fit_transform(x)
z=pd.DataFrame(z,columns=x.columns)

# %%
x=z

# %%
x
# Out:
#       Qualification  Experience    Rating   Profile      Area      City
# 0          0.218934   -0.405657  1.316235  1.543016 -0.453899  0.397991
# 1          1.067505   -1.022950  1.230229 -1.472893  1.722364 -1.331496
# 2         -1.189133    1.778607 -0.876920  0.336652  0.153430 -1.331496
# 3          0.379790   -1.022950 -0.876920 -1.472893 -1.345427 -1.331496
# 4         -1.541150   -0.643077  1.316235 -1.472893 -0.302066 -0.899125
# ...             ...         ...       ...       ...       ...       ...
# 5956      -1.345326   -0.690561  1.230229  0.336652 -1.337640 -1.331496
# 5957       0.720150    0.069183 -0.876920  0.939834  0.476561 -0.899125
# 5958       0.720150    0.496539  1.187226  0.939834 -0.769243 -0.034381
# 5959       1.620008   -0.880498  0.886205  0.939834  1.663967  1.262735
# 5960      -0.191364   -0.785530  1.316235 -0.869711  0.717935 -0.034381
#
# [5961 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=42)

# %%
print(x_train.shape,'\t',x_test.shape)
print(y_train.shape,'\t',y_test.shape)
# Out:
# (4470, 6) 	 (1491, 6)
# (4470,) 	 (1491,)

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
model=[LinearRegression(),DecisionTreeRegressor(),KNeighborsRegressor(),SVR(),Lasso(),Ridge(),ElasticNet()]

# %%
for m in model:
    m.fit(x_train,y_train)
    print('score of' ,m,'is:',m.score(x_train,y_train))
    pred=m.predict(x_test)
    print('Error')
    print('mean_absolute_error', mean_absolute_error(y_test,pred))
    print('mean_squared_error', mean_squared_error(y_test,pred) )
    print('r2 score', r2_score(y_test,pred))  
    print('*************************************')
    print('\n')
# Out:
# score of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False) is: 0.057819349044674784
# Error
# mean_absolute_error 148.97038296378977
# mean_squared_error 33172.70551579441
# r2 score 0.04139513135613182
# *************************************
#
#
# score of DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best') is: 0.9973482056233564
# Error
# mean_absolute_error 171.30896490051418
# mean_squared_error 57497.933899694464
# r2 score -0.661540670747141
# *************************************
#
#
# score of KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
# ...

# %%
from sklearn.model_selection import cross_val_score
for m in model:
    score=cross_val_score(m,x,y,cv=4,scoring='r2')
    print('score of' ,m,'is:')
    print('score:',score)
    print('mean square', score.mean())
    print('standard deviation',score.std() )  
    print('*************************************')
    print('\n')
# Out:
# score of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False) is:
# score: [0.06326848 0.05263908 0.03770445 0.05291532]
# mean square 0.0516318315804738
# standard deviation 0.00911105520050665
# *************************************
#
#
# score of DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best') is:
# score: [-0.64118031 -0.53480203 -0.58010711 -0.5018871 ]
# mean square -0.564494135966074
# standard deviation 0.052263269379518404
# *************************************
#
#
# score of KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
# ...

# %% [markdown]
# Linear Regression is giving us the best result so we will proceed with that

# %%
#using random forest to improve accuracy

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(n_estimators=20,random_state=59)
rf.fit(x_train,y_train)
print(rf.score(x_train,y_train))
predrf=rf.predict(x_test)
print('\n')

print('mean_absolute_error', mean_absolute_error(y_test,predrf))
print('mean_squared_error', mean_squared_error(y_test,predrf) )
print('root mean_squared_error', np.sqrt(mean_squared_error(y_test,predrf)))
print('r2 score', r2_score(y_test,predrf))  
print('*************************************')
print('\n')
# Out:
# 0.8617200762665689
#
#
# mean_absolute_error 134.42616492606433
# mean_squared_error 31101.02755212682
# root mean_squared_error 176.35483421819436
# r2 score 0.10126123366389861
# *************************************

# %%
from sklearn.ensemble import AdaBoostRegressor
lasso=Lasso()
adb=AdaBoostRegressor(base_estimator=lasso,n_estimators=20,learning_rate=0.1,random_state=59)
adb.fit(x_train,y_train)
print(adb.score(x_train,y_train))
predadb=adb.predict(x_test)
print('\n')

print('mean_absolute_error', mean_absolute_error(y_test,predadb))
print('mean_squared_error', mean_squared_error(y_test,predadb) )
print('root mean_squared_error', np.sqrt(mean_squared_error(y_test,predadb)))
print('r2 score', r2_score(y_test,predadb))  
print('*************************************')
print('\n')
# Out:
# 0.053607486692275996
#
#
# mean_absolute_error 151.32367858152634
# mean_squared_error 33351.10369377969
# root mean_squared_error 182.62284548703016
# r2 score 0.03623988823336466
# *************************************

# %% [markdown]
# As random forest is giving best accuracy so i am saving the model

# %%
import pickle
filename='Drconsultation.pkl'
pickle.dump(rf,open(filename, 'wb'))

# %%
drt=pd.read_csv('Doctortest')

# %%
drt
# Out:
#                                         Qualification           Experience  \
# 0                                                MBBS  35 years experience
# 1          MBBS, Diploma in Otorhinolaryngology (DLO)  31 years experience
# 2                                          MBBS, DDVL  40 years experience
# 3                                                BAMS   0 years experience
# 4     BDS, MDS - Conservative Dentistry & Endodontics  16 years experience
# ...                                               ...                  ...
# 1982                         BAMS, Doctor of Medicine  10 years experience
# 1983   MD - Dermatology , Venereology & Leprosy, MBBS   4 years experience
# 1984         MBBS, MD / MS - Obstetrics & Gynaecology   9 years experience
# 1985                                              BDS  12 years experience
# 1986   MBBS, MD - Dermatology , Venereology & Leprosy   8 years experience
#
#      Rating                        Place           Profile  \
# ...

# %%
drt.dtypes
# Out:
# Qualification         object
# Experience            object
# Rating                object
# Place                 object
# Profile               object
# Miscellaneous_Info    object
# dtype: object

# %%
drt.describe()
# Out:
#        Qualification           Experience Rating                 Place  \
# count           1987                 1987    897                  1981
# unique           630                   57     36                   592
# top             BAMS  10 years experience   100%  Andheri West, Mumbai
# freq             153                  110    223                    27
#
#                  Profile                                 Miscellaneous_Info
# count               1987                                               1153
# unique                 6                                               1084
# top     General Medicine  Acrylic Partial Denture Crowns and Bridges Fix...
# freq                 444                                                 10

# %%
drt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1987 entries, 0 to 1986
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Qualification       1987 non-null   object
#  1   Experience          1987 non-null   object
#  2   Rating              897 non-null    object
#  3   Place               1981 non-null   object
#  4   Profile             1987 non-null   object
#  5   Miscellaneous_Info  1153 non-null   object
# dtypes: object(6)
# memory usage: 93.3+ KB

# %% [markdown]
# null values present in the data

# %%
for i in drt['Experience'].value_counts().index:
    rd=i.split()
    drt['Experience'].replace(i,int(rd[0]),inplace=True)

# %%
drt['Area']=drt['Place'].str.rsplit(',',1).str.get(0)
drt['City']=drt['Place'].str.rsplit(',',1).str.get(1)

# %%
drt
# Out:
#                                         Qualification  Experience Rating  \
# 0                                                MBBS          35    NaN
# 1          MBBS, Diploma in Otorhinolaryngology (DLO)          31    NaN
# 2                                          MBBS, DDVL          40    70%
# 3                                                BAMS           0    NaN
# 4     BDS, MDS - Conservative Dentistry & Endodontics          16   100%
# ...                                               ...         ...    ...
# 1982                         BAMS, Doctor of Medicine          10    NaN
# 1983   MD - Dermatology , Venereology & Leprosy, MBBS           4    NaN
# 1984         MBBS, MD / MS - Obstetrics & Gynaecology           9    NaN
# 1985                                              BDS          12    98%
# 1986   MBBS, MD - Dermatology , Venereology & Leprosy           8    NaN
#
#                             Place           Profile  \
# ...

# %%
# Dropping place as we have extracted the info

# %%
drt.drop(['Place','Miscellaneous_Info'],axis=1,inplace=True)

# %%
drt
# Out:
#                                         Qualification  Experience Rating  \
# 0                                                MBBS          35    NaN
# 1          MBBS, Diploma in Otorhinolaryngology (DLO)          31    NaN
# 2                                          MBBS, DDVL          40    70%
# 3                                                BAMS           0    NaN
# 4     BDS, MDS - Conservative Dentistry & Endodontics          16   100%
# ...                                               ...         ...    ...
# 1982                         BAMS, Doctor of Medicine          10    NaN
# 1983   MD - Dermatology , Venereology & Leprosy, MBBS           4    NaN
# 1984         MBBS, MD / MS - Obstetrics & Gynaecology           9    NaN
# 1985                                              BDS          12    98%
# 1986   MBBS, MD - Dermatology , Venereology & Leprosy           8    NaN
#
#                Profile              Area        City
# ...

# %%
drt['Rating'].fillna('-99999%',inplace=True)
for i in drt['Rating'].value_counts().index:
    drt['Rating'].replace(i,int(i[:-1]),inplace=True)

# %%
drt
# Out:
#                                   Qualification Experience  Rating  \
# 0                                          MBBS         35  -99999
# 1        MBBS,DiplomainOtorhinolaryngology(DLO)         31  -99999
# 2                                     MBBS,DDVL         40      70
# 3                                          BAMS          0  -99999
# 4     BDS,MDS-ConservativeDentistry&Endodontics         16     100
# ...                                         ...        ...     ...
# 1982                      BAMS,DoctorofMedicine         10  -99999
# 1983    MD-Dermatology,Venereology&Leprosy,MBBS          4  -99999
# 1984          MBBS,MD/MS-Obstetrics&Gynaecology          9  -99999
# 1985                                        BDS         12      98
# 1986    MBBS,MD-Dermatology,Venereology&Leprosy          8  -99999
#
#                Profile             Area       City
# 0     General Medicine    GhatkoparEast     Mumbai
# 1       ENT Specialist  WestMarredpally  Hyderabad
# ...

# %%
import re
for col in ['Qualification','Experience','Area','City']:
    drt[col]=drt[col].apply(lambda x: re.sub(' +','',str(x)))

# %%
drt
# Out:
#                                   Qualification Experience  Rating  \
# 0                                          MBBS         35  -99999
# 1        MBBS,DiplomainOtorhinolaryngology(DLO)         31  -99999
# 2                                     MBBS,DDVL         40      70
# 3                                          BAMS          0  -99999
# 4     BDS,MDS-ConservativeDentistry&Endodontics         16     100
# ...                                         ...        ...     ...
# 1982                      BAMS,DoctorofMedicine         10  -99999
# 1983    MD-Dermatology,Venereology&Leprosy,MBBS          4  -99999
# 1984          MBBS,MD/MS-Obstetrics&Gynaecology          9  -99999
# 1985                                        BDS         12      98
# 1986    MBBS,MD-Dermatology,Venereology&Leprosy          8  -99999
#
#                Profile             Area       City
# 0     General Medicine    GhatkoparEast     Mumbai
# 1       ENT Specialist  WestMarredpally  Hyderabad
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
columns=['Qualification','Profile','Area','City']
for col in columns:
    drt[col]=le.fit_transform(drt[col])

# %%
drt
# Out:
#       Qualification Experience  Rating  Profile  Area  City
# 0               241         35  -99999        4   142     6
# 1               340         31  -99999        3   577     5
# 2               258         40      70        2   212     1
# 3                 6          0  -99999        0   373     3
# 4                80         16     100        1   231     0
# ...             ...        ...     ...      ...   ...   ...
# 1982             17         10  -99999        0    58     0
# 1983            553          4  -99999        2    96     1
# 1984            474          9  -99999        4   423     1
# 1985             51         12      98        1    26     0
# 1986            406          8  -99999        2   393     1
#
# [1987 rows x 6 columns]

# %%
# loading the saved model for predictions

# %%
fitted_model=pickle.load(open('Drconsultation.pkl','rb'))

# %%
fitted_model
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=20, n_jobs=None, oob_score=False,
#                       random_state=59, verbose=0, warm_start=False)

# %%
prediction=fitted_model.predict(drt)

# %%
prediction
# Out:
# array([425. , 425. , 552.5, ..., 432.5, 625. , 432.5])
