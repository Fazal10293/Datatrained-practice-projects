# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
heart=pd.read_csv('heartdiseasedata.csv')

# %%
heart
# Out:
#      63  1  4  140  260  0  1.1  112 1.2     3  2  ? ?.1  2.1
# 0    44  1  4  130  209  0    1  127   0     0  ?  ?   ?    0
# 1    60  1  4  132  218  0    1  140   1   1.5  3  ?   ?    2
# 2    55  1  4  142  228  0    1  149   1   2.5  1  ?   ?    1
# 3    66  1  3  110  213  1    2   99   1   1.3  2  ?   ?    0
# 4    66  1  3  120    0  0    1  120   0  -0.5  1  ?   ?    0
# ..   .. .. ..  ...  ... ..  ...  ...  ..   ... .. ..  ..  ...
# 194  54  0  4  127  333  1    1  154   0     0  ?  ?   ?    1
# 195  62  1  1    ?  139  0    1    ?   ?     ?  ?  ?   ?    0
# 196  55  1  4  122  223  1    1  100   0     0  ?  ?   6    2
# 197  58  1  4    ?  385  1    2    ?   ?     ?  ?  ?   ?    0
# 198  62  1  2  120  254  0    2   93   1     0  ?  ?   ?    1
#
# [199 rows x 14 columns]

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   63      199 non-null    int64
#  1   1       199 non-null    int64
#  2   4       199 non-null    int64
#  3   140     199 non-null    object
#  4   260     199 non-null    object
#  5   0       199 non-null    object
#  6   1.1     199 non-null    int64
#  7   112     199 non-null    object
#  8   1.2     199 non-null    object
#  9   3       199 non-null    object
#  10  2       199 non-null    object
#  11  ?       199 non-null    object
#  12  ?.1     199 non-null    object
#  13  2.1     199 non-null    int64
# dtypes: int64(5), object(9)
# memory usage: 21.9+ KB

# %%
#statistical summary
heart.describe()
# Out:
#                63           1           4         1.1         2.1
# count  199.000000  199.000000  199.000000  199.000000  199.000000
# mean    59.331658    0.969849    3.502513    0.733668    1.517588
# std      7.827080    0.171433    0.796928    0.684918    1.222038
# min     35.000000    0.000000    1.000000    0.000000    0.000000
# 25%     55.000000    1.000000    3.000000    0.000000    0.000000
# 50%     60.000000    1.000000    4.000000    1.000000    1.000000
# 75%     64.000000    1.000000    4.000000    1.000000    3.000000
# max     77.000000    1.000000    4.000000    2.000000    4.000000

# %%
heart.columns=['Age', 'Sex','Cp','Trestbps','Chol','Fbs','Restecg','Thalach','Exang','Oldspeak','Slope','Ca','Thal','Target']

# %%
heart
# Out:
#      Age  Sex  Cp Trestbps Chol Fbs  Restecg Thalach Exang Oldspeak Slope Ca  \
# 0     44    1   4      130  209   0        1     127     0        0     ?  ?
# 1     60    1   4      132  218   0        1     140     1      1.5     3  ?
# 2     55    1   4      142  228   0        1     149     1      2.5     1  ?
# 3     66    1   3      110  213   1        2      99     1      1.3     2  ?
# 4     66    1   3      120    0   0        1     120     0     -0.5     1  ?
# ..   ...  ...  ..      ...  ...  ..      ...     ...   ...      ...   ... ..
# 194   54    0   4      127  333   1        1     154     0        0     ?  ?
# 195   62    1   1        ?  139   0        1       ?     ?        ?     ?  ?
# 196   55    1   4      122  223   1        1     100     0        0     ?  ?
# 197   58    1   4        ?  385   1        2       ?     ?        ?     ?  ?
# 198   62    1   2      120  254   0        2      93     1        0     ?  ?
#
#     Thal  Target
# 0      ?       0
# ...

# %% [markdown]
# Renamed the columns for better clarity

# %%
heart.dtypes
# Out:
# Age          int64
# Sex          int64
# Cp           int64
# Trestbps    object
# Chol        object
# Fbs         object
# Restecg      int64
# Thalach     object
# Exang       object
# Oldspeak    object
# Slope       object
# Ca          object
# Thal        object
# Target       int64
# dtype: object

# %%
heart.columns
# Out:
# Index(['Age', 'Sex', 'Cp', 'Trestbps', 'Chol', 'Fbs', 'Restecg', 'Thalach',
#        'Exang', 'Oldspeak', 'Slope', 'Ca', 'Thal', 'Target'],
#       dtype='object')

# %%
heart.shape
# Out:
# (199, 14)

# %%
heart.isnull().sum()
# Out:
# Age         0
# Sex         0
# Cp          0
# Trestbps    0
# Chol        0
# Fbs         0
# Restecg     0
# Thalach     0
# Exang       0
# Oldspeak    0
# Slope       0
# Ca          0
# Thal        0
# Target      0
# dtype: int64

# %%
#univariate analysis

# %%
heart['Age'].plot.hist()

# %% [markdown]
# Maximum people were of age group between 55 to 65

# %%
heart['Sex'].value_counts()
# Out:
# 1    193
# 0      6
# Name: Sex, dtype: int64

# %% [markdown]
# No proper evidence in data for male or female

# %%
heart['Sex'].hist()

# %% [markdown]
# as a hit and trial method we can consider 0 as female and 1 as male

# %%
heart['Trestbps'].value_counts()
# Out:
# ?      56
# 120    16
# 130    15
# 140     9
# 150     9
# 110     9
# 160     8
# 122     6
# 142     5
# 126     4
# 144     4
# 134     4
# 170     4
# 128     4
# 136     4
# 124     4
# 132     3
# 158     3
# 104     2
# 112     2
# 155     2
# 116     2
# 138     2
# 152     2
# 180     2
# 125     2
# 154     2
# 100     1
# 127     1
# 102     1
# 118     1
# 135     1
# 114     1
# 0       1
# 146     1
# 96      1
# 106     1
# 172     1
# 156     1
# 178     1
# 190     1
# Name: Trestbps, dtype: int64

# %%
#we have one data with 0 and ? contains 56 values, so need to remove those

# %%
#this will replace all ? to NaN, it will be helpfull in filling mean and median to columns
heart=heart.replace("?","NaN")

# %%
plt.figure(figsize=(16,8))
plt.xticks(rotation=90)
sns.countplot(x='Chol',data=heart)
plt.xlabel('Chol')
plt.ylabel('Count')
plt.title('Chol vs Count of heart disease')
# Out:
# Text(0.5, 1.0, 'Chol vs Count of heart disease')

# %%
#This graph suggest that many people didnt had cholestrol

# %%
plt.figure(figsize=(12,8))
plt.xticks(rotation=90)
sns.distplot(heart['Trestbps'])
plt.xlabel('Trestbps')
plt.ylabel('Count')
plt.title('Trest bps vs Count of heart disease')
# Out:
# Text(0.5, 1.0, 'Trest bps vs Count of heart disease')

# %%
#The max data is distributed from 125 to 175 range

# %%
heart.columns
# Out:
# Index(['Age', 'Sex', 'Cp', 'Trestbps', 'Chol', 'Fbs', 'Restecg', 'Thalach',
#        'Exang', 'Oldspeak', 'Slope', 'Ca', 'Thal', 'Target'],
#       dtype='object')

# %%
plt.figure(figsize=(12,8))
plt.xticks(rotation=90)
sns.distplot(heart['Chol'])

# %%
#max cholestrol level lies between 175 to 250 Range

# %%
heart
# Out:
#      Age  Sex  Cp Trestbps Chol Fbs  Restecg Thalach Exang Oldspeak Slope  \
# 0     44    1   4      130  209   0        1     127     0        0   NaN
# 1     60    1   4      132  218   0        1     140     1      1.5     3
# 2     55    1   4      142  228   0        1     149     1      2.5     1
# 3     66    1   3      110  213   1        2      99     1      1.3     2
# 4     66    1   3      120    0   0        1     120     0     -0.5     1
# ..   ...  ...  ..      ...  ...  ..      ...     ...   ...      ...   ...
# 194   54    0   4      127  333   1        1     154     0        0   NaN
# 195   62    1   1      NaN  139   0        1     NaN   NaN      NaN   NaN
# 196   55    1   4      122  223   1        1     100     0        0   NaN
# 197   58    1   4      NaN  385   1        2     NaN   NaN      NaN   NaN
# 198   62    1   2      120  254   0        2      93     1        0   NaN
#
#       Ca Thal  Target
# 0    NaN  NaN       0
# 1    NaN  NaN       2
# ...

# %%
heart['Ca'].value_counts()
# Out:
# NaN    197
# 0        2
# Name: Ca, dtype: int64

# %%
heart['Thal'].value_counts()
# Out:
# NaN    165
# 7       22
# 6        8
# 3        4
# Name: Thal, dtype: int64

# %% [markdown]
# in column (Ca) almost 98% NaN values ans in (Thal) columns almost 90% so we can drop these two columns as of now.

# %%
heart.drop(['Ca','Thal'],axis=1,inplace=True)

# %%
heart
# Out:
#      Age  Sex  Cp Trestbps Chol Fbs  Restecg Thalach Exang Oldspeak Slope  \
# 0     44    1   4      130  209   0        1     127     0        0   NaN
# 1     60    1   4      132  218   0        1     140     1      1.5     3
# 2     55    1   4      142  228   0        1     149     1      2.5     1
# 3     66    1   3      110  213   1        2      99     1      1.3     2
# 4     66    1   3      120    0   0        1     120     0     -0.5     1
# ..   ...  ...  ..      ...  ...  ..      ...     ...   ...      ...   ...
# 194   54    0   4      127  333   1        1     154     0        0   NaN
# 195   62    1   1      NaN  139   0        1     NaN   NaN      NaN   NaN
# 196   55    1   4      122  223   1        1     100     0        0   NaN
# 197   58    1   4      NaN  385   1        2     NaN   NaN      NaN   NaN
# 198   62    1   2      120  254   0        2      93     1        0   NaN
#
#      Target
# 0         0
# 1         2
# 2         1
# 3         0
# ...

# %%
heart['Slope'].value_counts()
# Out:
# NaN    102
# 2       52
# 3       29
# 1       16
# Name: Slope, dtype: int64

# %%
heart.drop(['Slope'],axis=1,inplace=True)

# %%
heart
# Out:
#      Age  Sex  Cp Trestbps Chol Fbs  Restecg Thalach Exang Oldspeak  Target
# 0     44    1   4      130  209   0        1     127     0        0       0
# 1     60    1   4      132  218   0        1     140     1      1.5       2
# 2     55    1   4      142  228   0        1     149     1      2.5       1
# 3     66    1   3      110  213   1        2      99     1      1.3       0
# 4     66    1   3      120    0   0        1     120     0     -0.5       0
# ..   ...  ...  ..      ...  ...  ..      ...     ...   ...      ...     ...
# 194   54    0   4      127  333   1        1     154     0        0       1
# 195   62    1   1      NaN  139   0        1     NaN   NaN      NaN       0
# 196   55    1   4      122  223   1        1     100     0        0       2
# 197   58    1   4      NaN  385   1        2     NaN   NaN      NaN       0
# 198   62    1   2      120  254   0        2      93     1        0       1
#
# [199 rows x 11 columns]

# %%
heart=pd.DataFrame(heart)

# %%
import re
heart['Thalach']=heart['Thalach'].apply(lambda x: re.sub(' +','',str(x)))

# %%
heart=heart.replace(np.NaN,heart['Thalach'].mean())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1302         try:
# -> 1303             x = float(x)
#    1304         except ValueError:
#
# ValueError: could not convert string to float: '...'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1306             try:
# -> 1307                 x = complex(x)
#    1308             except ValueError:
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-1718e0d25522> in <module>
# ...
