# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
covid=pd.read_csv('covid_data.csv')

# %%
covid
# Out:
#              Date             Country  Confirmed  Recovered  Deaths
# 0      2020-01-22         Afghanistan          0          0       0
# 1      2020-01-22             Albania          0          0       0
# 2      2020-01-22             Algeria          0          0       0
# 3      2020-01-22             Andorra          0          0       0
# 4      2020-01-22              Angola          0          0       0
# ...           ...                 ...        ...        ...     ...
# 23683  2020-05-26  West Bank and Gaza        429        365       3
# 23684  2020-05-26      Western Sahara          9          6       1
# 23685  2020-05-26               Yemen        249         10      49
# 23686  2020-05-26              Zambia        920        336       7
# 23687  2020-05-26            Zimbabwe         56         25       4
#
# [23688 rows x 5 columns]

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23688 entries, 0 to 23687
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       23688 non-null  object
#  1   Country    23688 non-null  object
#  2   Confirmed  23688 non-null  int64
#  3   Recovered  23688 non-null  int64
#  4   Deaths     23688 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 925.4+ KB

# %%
covid.describe()
# Out:
#           Confirmed      Recovered        Deaths
# count  2.368800e+04   23688.000000  23688.000000
# mean   7.969368e+03    2581.801714    526.935030
# std    5.842109e+04   15143.101257   3992.815956
# min    0.000000e+00       0.000000      0.000000
# 25%    0.000000e+00       0.000000      0.000000
# 50%    1.800000e+01       1.000000      0.000000
# 75%    7.300000e+02     123.000000     13.000000
# max    1.680913e+06  384902.000000  98913.000000

# %%
covid.columns
# Out:
# Index(['Date', 'Country', 'Confirmed', 'Recovered', 'Deaths'], dtype='object')

# %%
covid.size
# Out:
# 118440

# %%
covid.shape
# Out:
# (23688, 5)

# %%
covid.dtypes
# Out:
# Date         object
# Country      object
# Confirmed     int64
# Recovered     int64
# Deaths        int64
# dtype: object

# %%
#univariate analysis

# %%
covid['Recovered'].plot.hist()

# %%
covid['Confirmed'].plot.hist()

# %%
covid['Deaths'].plot.hist()

# %%
sns.distplot(covid['Recovered'],bins=5)

# %%
sns.distplot(covid['Deaths'],bins=10)

# %%
#bivariate analysis

# %%
plt.scatter(covid['Recovered'],covid['Confirmed'])

# %%
plt.scatter(covid['Recovered'],covid['Deaths'])

# %% [markdown]
# this graph shows around 100000 people died of this virus and more than 150000 people recovered

# %%
plt.scatter(covid['Confirmed'],covid['Deaths'])

# %% [markdown]
# Many people confirmed but there were only few deaths.it is linearly related.

# %%
plt.scatter(covid['Country'],covid['Deaths'])

# %%
covid.groupby('Country').Deaths.sum()
# Out:
# Country
# Afghanistan            4669
# Albania                1629
# Algeria               23232
# Andorra                2219
# Angola                  131
#                       ...
# West Bank and Gaza      113
# Western Sahara            1
# Yemen                   460
# Zambia                  215
# Zimbabwe                199
# Name: Deaths, Length: 188, dtype: int64

# %%
covid.groupby('Country').Deaths.sum().plot.bar()

# %%
covid.groupby('Date').Deaths.sum().plot.bar()

# %%
covid.plot.scatter('Country','Deaths')

# %%
sns.pairplot(covid)

# %%
covid.groupby(covid['Country']).Confirmed.sum()
# Out:
# Country
# Afghanistan           185236
# Albania                41253
# Algeria               240070
# Andorra                41573
# Angola                  1892
#                        ...
# West Bank and Gaza     19971
# Western Sahara           307
# Yemen                   2696
# Zambia                 15285
# Zimbabwe                1760
# Name: Confirmed, Length: 188, dtype: int64

# %% [markdown]
# Highest number of cases confirmed in Afghanistan and lowest was found in zimbabwe

# %%
corr_hmap=covid.corr()
plt.figure(figsize=(8,7))
sns.heatmap(corr_hmap,annot=True)
plt.show()
